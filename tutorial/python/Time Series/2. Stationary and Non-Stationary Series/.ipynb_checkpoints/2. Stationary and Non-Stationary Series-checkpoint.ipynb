# %%
# Coded by Carlos Goes (Instituto Mercado Popular)

# This do file aims at
# 1. generating stationary and non-stationary data
# 2. providing examples of spurious regressions

# Import packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns

# Define length of time series

tlength = 10000

# Define number of non-stationary series to be created

wide = 5

# %%
# Generate and plot a stationary series using the built-in command

stationary = np.random.randn(tlength)
plt.plot(stationary)
plt.show()
sns.despine()

# %%
# Generate and plot a stationary series using a loop

holder = [] 

for i in range(tlength):
    e = np.random.randn()
    holder.append(e)

plt.plot(holder)
plt.show()

# %%
# Generate and plot a non-stationary series using a loop

holder = [] 

for i in range(tlength):
    if i == 0:  # generates a random observation for the first period
        b = np.random.randn()
        holder.append(b)    
    else: # adds a new random number to the past observations for subsequent observations
        e = np.random.randn()
        b = holder[i-1] + e
        holder.append(b)

plt.plot(holder, 'green')
plt.show()

# %%
# Generalize non-stationary as a program

def nonstationary(n):
    holder = []
    for i in range(n):
        if i == 0:
            b = np.random.randn()
            holder.append(b)    
        else:
            e = np.random.randn()
            b = holder[i-1] + e
            holder.append(b)
    return holder

# %%
# Generate n nonstationary series and compare them to a stationary series

matrixns = np.matrix([[0 for x in range(wide)] for y in range(tlength)])

for i in range(wide):
    data = nonstationary(tlength)
    matrixns[:,i] = np.transpose(np.matrix(data))
    plt.plot(matrixns[:,i], 'black')

plt.plot(stationary, 'red')
    
plt.show()

# %%
# Generalize stationary series generators as a program

def arstationary(n,alpha):
    if alpha >= 1:
        print("Alpha needs to be smaller than one")
    else:
        holder = []
        for i in range(n):
            if i == 0:
                b = np.random.randn()
                holder.append(b)    
            else:
                e = np.random.randn()
                b = alpha * holder[i-1] + e
                holder.append(b)
        return holder

# %%
# Generate n nonstationary series and compare them to a stationary series

matrix = np.matrix([[0 for x in range(wide)] for y in range(tlength)])

for i in range(wide):
    data = arstationary(tlength,0.99)
    matrix[:,i] = np.transpose(np.matrix(data))
    plt.plot(matrix[:,i])
    
plt.show()

# %%
# Define dataframe from simulated series
df = pd.DataFrame(matrixns, columns=('a','b','c','d','e'))

fig, axs = plt.subplots(1, 3, sharey=True)
df.plot(kind='scatter', x='a', y='b', ax=axs[0], figsize=(10, 6))
df.plot(kind='scatter', x='b', y='c', ax=axs[1])
df.plot(kind='scatter', x='c', y='d', ax=axs[2])
plt.show()

# %%
# Fit Linear models
lm = smf.ols(formula='a ~ b', data = df).fit()
lm2 = smf.ols(formula='b ~ c', data = df).fit()
lm3 = smf.ols(formula='c ~ d', data = df).fit()
lm4 = smf.ols(formula='d ~ e', data = df).fit()

# %%
# Print outputs
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      a   R-squared:                       0.551
# Model:                            OLS   Adj. R-squared:                  0.551
# Method:                 Least Squares   F-statistic:                 1.228e+04
# Date:                Tue, 21 Mar 2017   Prob (F-statistic):               0.00
# Time:                        19:15:39   Log-Likelihood:                -40822.
# No. Observations:               10000   AIC:                         8.165e+04
# Df Residuals:                    9998   BIC:                         8.166e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    -30.5259      0.285   -107.072      0.000       -31.085   -29.967
# b             -0.4938      0.004   -110.806      0.000        -0.503    -0.485
# ==============================================================================
# Omnibus:                      255.217   Durbin-Watson:                   0.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              183.025
# Skew:                          -0.229   Prob(JB):                     1.81e-40
# Kurtosis:                       2.521   Cond. No.                         127.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      b   R-squared:                       0.489
# Model:                            OLS   Adj. R-squared:                  0.489
# Method:                 Least Squares   F-statistic:                     9564.
# Date:                Tue, 21 Mar 2017   Prob (F-statistic):               0.00
# Time:                        19:15:39   Log-Likelihood:                -45550.
# No. Observations:               10000   AIC:                         9.110e+04
# Df Residuals:                    9998   BIC:                         9.112e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -7.9652      0.687    -11.602      0.000        -9.311    -6.620
# c             -0.6264      0.006    -97.798      0.000        -0.639    -0.614
# ==============================================================================
# Omnibus:                      577.670   Durbin-Watson:                   0.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              288.900
# Skew:                           0.238   Prob(JB):                     1.85e-63
# Kurtosis:                       2.317   Cond. No.                         320.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      c   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     382.5
# Date:                Tue, 21 Mar 2017   Prob (F-statistic):           1.31e-83
# Time:                        19:15:39   Log-Likelihood:                -49818.
# No. Observations:               10000   AIC:                         9.964e+04
# Df Residuals:                    9998   BIC:                         9.965e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   -100.3145      0.354   -283.152      0.000      -101.009   -99.620
# d             -0.2047      0.010    -19.557      0.000        -0.225    -0.184
# ==============================================================================
# Omnibus:                      862.727   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1131.674
# Skew:                           0.746   Prob(JB):                    1.82e-246
# Kurtosis:                       3.699   Cond. No.                         34.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      d   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     308.7
# Date:                Tue, 21 Mar 2017   Prob (F-statistic):           4.42e-68
# Time:                        19:15:39   Log-Likelihood:                -49209.
# No. Observations:               10000   AIC:                         9.842e+04
# Df Residuals:                    9998   BIC:                         9.844e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      7.2158      0.402     17.942      0.000         6.427     8.004
# e              0.1563      0.009     17.570      0.000         0.139     0.174
# ==============================================================================
# Omnibus:                      518.421   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              366.371
# Skew:                          -0.363   Prob(JB):                     2.78e-80
# Kurtosis:                       2.407   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
