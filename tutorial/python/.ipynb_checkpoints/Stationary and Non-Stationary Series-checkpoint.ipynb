# %%
# Coded by Carlos Goes (Instituto Mercado Popular)

# This do file aims at
# 1. generating stationary and non-stationary data
# 2. providing examples of spurious regressions

# Import packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# Define length of time series

tlength = 10000

# Define number of non-stationary series to be created

wide = 5

# %%
# Generate and plot a stationary series using the built-in command

stationary = np.random.randn(tlength)
plt.plot(stationary)
plt.show()

# %%
# Generate and plot a stationary series using a loop

holder = [] 

for i in range(tlength):
    e = np.random.randn()
    holder.append(e)

plt.plot(holder)
plt.show()

# %%
# Generate and plot a non-stationary series using a loop

holder = [] 

for i in range(tlength):
    if i == 0:  # generates a random observation for the first period
        b = np.random.randn()
        holder.append(b)    
    else: # adds a new random number to the past observations for subsequent observations
        e = np.random.randn()
        b = holder[i-1] + e
        holder.append(b)

plt.plot(holder, 'green')
plt.show()

# %%
# Generalize non-stationary as a program

def nonstationary(n):
    holder = []
    for i in range(n):
        if i == 0:
            b = np.random.randn()
            holder.append(b)    
        else:
            e = np.random.randn()
            b = holder[i-1] + e
            holder.append(b)
    return holder

# %%
# Generate n nonstationary series and compare them to a stationary series

matrixns = np.matrix([[0 for x in range(wide)] for y in range(tlength)])

for i in range(wide):
    data = nonstationary(tlength)
    matrixns[:,i] = np.transpose(np.matrix(data))
    plt.plot(matrixns[:,i], 'black')

plt.plot(stationary, 'red')
    
plt.show()

# %%
# Generalize stationary series generators as a program

def arstationary(n,alpha):
    if alpha >= 1:
        print("Alpha needs to be smaller than one")
    else:
        holder = []
        for i in range(n):
            if i == 0:
                b = np.random.randn()
                holder.append(b)    
            else:
                e = np.random.randn()
                b = alpha * holder[i-1] + e
                holder.append(b)
        return holder

# %%
# Generate n nonstationary series and compare them to a stationary series

matrix = np.matrix([[0 for x in range(wide)] for y in range(tlength)])

for i in range(wide):
    data = arstationary(tlength,0.99)
    matrix[:,i] = np.transpose(np.matrix(data))
    plt.plot(matrix[:,i])
    
plt.show()

# %%
# Define dataframe from simulated series
df = pd.DataFrame(matrixns, columns=('a','b','c','d','e'))
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      a   R-squared:                       0.083
# Model:                            OLS   Adj. R-squared:                  0.083
# Method:                 Least Squares   F-statistic:                     903.2
# Date:                Tue, 28 Feb 2017   Prob (F-statistic):          4.62e-190
# Time:                        00:39:24   Log-Likelihood:                -52270.
# No. Observations:               10000   AIC:                         1.045e+05
# Df Residuals:                    9998   BIC:                         1.046e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -2.4018      0.699     -3.438      0.001        -3.771    -1.033
# b             -0.8131      0.027    -30.054      0.000        -0.866    -0.760
# ==============================================================================
# Omnibus:                      360.292   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              173.433
# Skew:                          -0.102   Prob(JB):                     2.18e-38
# Kurtosis:                       2.388   Cond. No.                         40.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Fit Linear models
lm = smf.ols(formula='a ~ b', data = df).fit()
lm2 = smf.ols(formula='b ~ c', data = df).fit()
lm3 = smf.ols(formula='c ~ d', data = df).fit()
lm4 = smf.ols(formula='d ~ e', data = df).fit()

# %%
# Print outputs
lm.summary()

# %%
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      b   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     554.2
# Date:                Tue, 28 Feb 2017   Prob (F-statistic):          2.61e-119
# Time:                        00:39:24   Log-Likelihood:                -42049.
# No. Observations:               10000   AIC:                         8.410e+04
# Df Residuals:                    9998   BIC:                         8.412e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     18.8704      0.166    113.546      0.000        18.545    19.196
# c             -0.0871      0.004    -23.541      0.000        -0.094    -0.080
# ==============================================================================
# Omnibus:                     1361.278   Durbin-Watson:                   0.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              492.655
# Skew:                           0.325   Prob(JB):                    1.05e-107
# Kurtosis:                       2.128   Cond. No.                         46.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      c   R-squared:                       0.119
# Model:                            OLS   Adj. R-squared:                  0.119
# Method:                 Least Squares   F-statistic:                     1349.
# Date:                Tue, 28 Feb 2017   Prob (F-statistic):          4.66e-277
# Time:                        00:39:25   Log-Likelihood:                -51357.
# No. Observations:               10000   AIC:                         1.027e+05
# Df Residuals:                    9998   BIC:                         1.027e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -2.2582      0.460     -4.910      0.000        -3.160    -1.357
# d              0.3150      0.009     36.722      0.000         0.298     0.332
# ==============================================================================
# Omnibus:                     1415.813   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              762.449
# Skew:                           0.532   Prob(JB):                    2.73e-166
# Kurtosis:                       2.165   Cond. No.                         60.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      d   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     484.6
# Date:                Tue, 28 Feb 2017   Prob (F-statistic):          6.46e-105
# Time:                        00:39:25   Log-Likelihood:                -52656.
# No. Observations:               10000   AIC:                         1.053e+05
# Df Residuals:                    9998   BIC:                         1.053e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    -31.6690      0.584    -54.229      0.000       -32.814   -30.524
# e              0.4822      0.022     22.014      0.000         0.439     0.525
# ==============================================================================
# Omnibus:                     3320.254   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              478.460
# Skew:                           0.054   Prob(JB):                    1.27e-104
# Kurtosis:                       1.934   Cond. No.                         33.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
