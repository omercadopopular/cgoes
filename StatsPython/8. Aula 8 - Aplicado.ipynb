# %%
# Importar pacotes

import pandas as pd

# %%
# Importar e inspecionar dataframe

dfiq = pd.read_excel('https://github.com/omercadopopular/cgoes/blob/master/StatsPython/data/brain_size.xlsx?raw=true')

dfiq
# Out:
#     Gender  FSIQ  VIQ  PIQ Weight Height  MRI_Count
# 1   Female   133  132  124    118   64.5     816932
# 2     Male   140  150  124      .   72.5    1001121
# 3     Male   139  123  150    143   73.3    1038437
# 4     Male   133  129  128    172   68.8     965353
# 5   Female   137  132  134    147   65.0     951545
# 6   Female    99   90  110    146   69.0     928799
# 7   Female   138  136  131    138   64.5     991305
# 8   Female    92   90   98    175   66.0     854258
# 9     Male    89   93   84    134   66.3     904858
# 10    Male   133  114  147    172   68.8     955466
# 11  Female   132  129  124    118   64.5     833868
# 12    Male   141  150  128    151   70.0    1079549
# 13    Male   135  129  124    155   69.0     924059
# 14  Female   140  120  147    155   70.5     856472
# 15  Female    96  100   90    146   66.0     878897
# 16  Female    83   71   96    135   68.0     865363
# 17  Female   132  132  120    127   68.5     852244
# 18    Male   100   96  102    178   73.5     945088
# 19  Female   101  112   84    136   66.3     808020
# 20    Male    80   77   86    180   70.0     889083
# 21    Male    83   83   86      .      .     892420
# 22    Male    97  107   84    186   76.5     905940
# 23  Female   135  129  134    122   62.0     790619
# 24    Male   139  145  128    132   68.0     955003
# 25  Female    91   86  102    114   63.0     831772
# 26    Male   141  145  131    171   72.0     935494
# 27  Female    85   90   84    140   68.0     798612
# 28    Male   103   96  110    187   77.0    1062462
# 29  Female    77   83   72    106   63.0     793549
# 30  Female   130  126  124    159   66.5     866662
# 31  Female   133  126  132    127   62.5     857782
# 32    Male   144  145  137    191   67.0     949589
# 33    Male   103   96  110    192   75.5     997925
# 34    Male    90   96   86    181   69.0     879987
# 35  Female    83   90   81    143   66.5     834344
# 36  Female   133  129  128    153   66.5     948066
# 37    Male   140  150  124    144   70.5     949395
# 38  Female    88   86   94    139   64.5     893983
# 39    Male    81   90   74    148   74.0     930016
# 40    Male    89   91   89    179   75.5     935863

# %% [markdown]
# Quais sao os problemas com essa importação?
# - Valores faltando
# - Nomes e unidades em inglês

# %%
# Assinalar valores faltando de forma correta

dfiq = pd.read_excel('https://github.com/omercadopopular/cgoes/blob/master/StatsPython/data/brain_size.xlsx?raw=true',
                     na_values=".")

dfiq
# Out:
#     Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 1   Female   133  132  124   118.0    64.5     816932
# 2     Male   140  150  124     NaN    72.5    1001121
# 3     Male   139  123  150   143.0    73.3    1038437
# 4     Male   133  129  128   172.0    68.8     965353
# 5   Female   137  132  134   147.0    65.0     951545
# 6   Female    99   90  110   146.0    69.0     928799
# 7   Female   138  136  131   138.0    64.5     991305
# 8   Female    92   90   98   175.0    66.0     854258
# 9     Male    89   93   84   134.0    66.3     904858
# 10    Male   133  114  147   172.0    68.8     955466
# 11  Female   132  129  124   118.0    64.5     833868
# 12    Male   141  150  128   151.0    70.0    1079549
# 13    Male   135  129  124   155.0    69.0     924059
# 14  Female   140  120  147   155.0    70.5     856472
# 15  Female    96  100   90   146.0    66.0     878897
# 16  Female    83   71   96   135.0    68.0     865363
# 17  Female   132  132  120   127.0    68.5     852244
# 18    Male   100   96  102   178.0    73.5     945088
# 19  Female   101  112   84   136.0    66.3     808020
# 20    Male    80   77   86   180.0    70.0     889083
# 21    Male    83   83   86     NaN     NaN     892420
# 22    Male    97  107   84   186.0    76.5     905940
# 23  Female   135  129  134   122.0    62.0     790619
# 24    Male   139  145  128   132.0    68.0     955003
# 25  Female    91   86  102   114.0    63.0     831772
# 26    Male   141  145  131   171.0    72.0     935494
# 27  Female    85   90   84   140.0    68.0     798612
# 28    Male   103   96  110   187.0    77.0    1062462
# 29  Female    77   83   72   106.0    63.0     793549
# 30  Female   130  126  124   159.0    66.5     866662
# 31  Female   133  126  132   127.0    62.5     857782
# 32    Male   144  145  137   191.0    67.0     949589
# 33    Male   103   96  110   192.0    75.5     997925
# 34    Male    90   96   86   181.0    69.0     879987
# 35  Female    83   90   81   143.0    66.5     834344
# 36  Female   133  129  128   153.0    66.5     948066
# 37    Male   140  150  124   144.0    70.5     949395
# 38  Female    88   86   94   139.0    64.5     893983
# 39    Male    81   90   74   148.0    74.0     930016
# 40    Male    89   91   89   179.0    75.5     935863

# %%
# Alterar nome das colunas

dfiq.columns = ['sexo', 'FSIQ', 'VIQ', 'PIQ', 'peso', 'altura', 'MRI_Count']

dfiq
# Out:
#       sexo  FSIQ  VIQ  PIQ   peso  altura  MRI_Count
# 1   Female   133  132  124  118.0    64.5     816932
# 2     Male   140  150  124    NaN    72.5    1001121
# 3     Male   139  123  150  143.0    73.3    1038437
# 4     Male   133  129  128  172.0    68.8     965353
# 5   Female   137  132  134  147.0    65.0     951545
# 6   Female    99   90  110  146.0    69.0     928799
# 7   Female   138  136  131  138.0    64.5     991305
# 8   Female    92   90   98  175.0    66.0     854258
# 9     Male    89   93   84  134.0    66.3     904858
# 10    Male   133  114  147  172.0    68.8     955466
# 11  Female   132  129  124  118.0    64.5     833868
# 12    Male   141  150  128  151.0    70.0    1079549
# 13    Male   135  129  124  155.0    69.0     924059
# 14  Female   140  120  147  155.0    70.5     856472
# 15  Female    96  100   90  146.0    66.0     878897
# 16  Female    83   71   96  135.0    68.0     865363
# 17  Female   132  132  120  127.0    68.5     852244
# 18    Male   100   96  102  178.0    73.5     945088
# 19  Female   101  112   84  136.0    66.3     808020
# 20    Male    80   77   86  180.0    70.0     889083
# 21    Male    83   83   86    NaN     NaN     892420
# 22    Male    97  107   84  186.0    76.5     905940
# 23  Female   135  129  134  122.0    62.0     790619
# 24    Male   139  145  128  132.0    68.0     955003
# 25  Female    91   86  102  114.0    63.0     831772
# 26    Male   141  145  131  171.0    72.0     935494
# 27  Female    85   90   84  140.0    68.0     798612
# 28    Male   103   96  110  187.0    77.0    1062462
# 29  Female    77   83   72  106.0    63.0     793549
# 30  Female   130  126  124  159.0    66.5     866662
# 31  Female   133  126  132  127.0    62.5     857782
# 32    Male   144  145  137  191.0    67.0     949589
# 33    Male   103   96  110  192.0    75.5     997925
# 34    Male    90   96   86  181.0    69.0     879987
# 35  Female    83   90   81  143.0    66.5     834344
# 36  Female   133  129  128  153.0    66.5     948066
# 37    Male   140  150  124  144.0    70.5     949395
# 38  Female    88   86   94  139.0    64.5     893983
# 39    Male    81   90   74  148.0    74.0     930016
# 40    Male    89   91   89  179.0    75.5     935863

# %%
# Alterar unidades e rótulos

lb_para_kg = lambda x: x / 2.2
in_para_cm = lambda x: x * 2.54

dfiq['peso'] = [lb_para_kg(pes) for pes in dfiq['peso']]
dfiq['altura'] = [in_para_cm(alt) for alt in dfiq['altura']]
dfiq['sexo'] = [string.replace("Female", "Feminino").replace("Male", "Masculino") for string in dfiq['sexo']]

dfiq
# Out:
#          sexo  FSIQ  VIQ  PIQ       peso   altura  MRI_Count
# PIQ       count      20.000000  2.000000e+01
#           mean      110.450000  1.116000e+02
#           std        21.946046  2.354033e+01
#           min        72.000000  7.400000e+01
#           25%        93.000000  8.600000e+01
#           50%       115.000000  1.170000e+02
#           75%       128.750000  1.280000e+02
#           max       147.000000  1.500000e+02
# VIQ       count      20.000000  2.000000e+01
#           mean      109.450000  1.152500e+02
#           std        21.670924  2.564099e+01
#           min        71.000000  7.700000e+01
#           25%        90.000000  9.525000e+01
#           50%       116.000000  1.105000e+02
#           75%       129.000000  1.450000e+02
#           max       136.000000  1.500000e+02
# altura    count      20.000000  1.900000e+01
#           mean      167.043100  1.814362e+02
#           std         5.812150  8.339152e+00
#           min       157.480000  1.684020e+02
#           25%       163.830000  1.750060e+02
#           50%       167.640000  1.790700e+02
#           75%       169.862500  1.873250e+02
#           max       179.070000  1.955800e+02
# peso      count      20.000000  1.800000e+01
#           mean       62.363636  7.565657e+01
#           std         7.706276  9.112571e+00
#           min        48.181818  6.000000e+01
#           25%        57.159091  6.761364e+01
#           50%        62.954545  7.818182e+01
#           75%        66.477273  8.215909e+01
#           max        79.545455  8.727273e+01

# %%
# %matplotlib inline

grupos.boxplot(column=['peso'], figsize=(16,8))
grupos.boxplot(column=['FSIQ'], figsize=(16,8))
# Out:
# Feminino          Axes(0.1,0.15;0.363636x0.75)
# Masculino    Axes(0.536364,0.15;0.363636x0.75)
# dtype: object

# %%
# Teste-t (diferenças de médias)
# Importar scipy

from scipy import stats

#Criar dataframes específicos para cada sexo, dropando valores faltantes

masc = dfiq[ dfiq['sexo'] == 'Masculino'].dropna()
fem = dfiq[ dfiq['sexo'] == 'Feminino'].dropna()

# %%
#Calcular estatísticas-t e p-valor para cada uma das variáves

t_stat, p_valor = stats.ttest_ind(masc['peso'], fem['peso'])
print("P-valor do teste-t de médias iguais de peso " +
      "para ambos os sexos: {:.2f}".format(p_valor))

t_stat, p_valor = stats.ttest_ind(masc['FSIQ'], fem['FSIQ'])
print("P-valor do teste-t de médias iguais de QI " +
      "para ambos os sexos: {:.2f}".format(p_valor))
# Out:
# P-valor do teste-t de médias iguais de peso para ambos os sexos: 0.00
# P-valor do teste-t de médias iguais de QI para ambos os sexos: 0.66

# %%
# Teste-F (múltiplos grupos)

# Scipy
#Calcular estatísticas-f e p-valor para cada uma das variáveis

f_stat, f_pvalue = stats.f_oneway(masc['peso'], fem['peso'])
print("P-valor do F-teste de médias iguais de peso " +
      "para ambos os sexos: {:.2f}".format(f_pvalue))

f_stat, f_pvalue = stats.f_oneway(masc['FSIQ'], fem['FSIQ'])
print("P-valor do F-teste de médias iguais de peso " +
      "para ambos os sexos: {:.2f}".format(f_pvalue))
# Out:
# P-valor do F-teste de médias iguais de peso para ambos os sexos: 0.00
# P-valor do F-teste de médias iguais de peso para ambos os sexos: 0.66

# %%
# Statsmodels
# Mesmo procedimento, utilizando outro pacote

# Statsmodels

import statsmodels.formula.api as smf

model1 = smf.ols("peso ~ C(sexo)", data=dfiq.dropna()).fit()
print("P-valor do F-teste de médias iguais de peso " +
      "para ambos os sexos: {:.2f}".format(model1.f_pvalue))

model2 = smf.ols("FSIQ ~ C(sexo)", data=dfiq.dropna()).fit()
print("P-valor do F-teste de médias iguais de QI " +
      "para ambos os sexos: {:.2f}".format(model2.f_pvalue))
# Out:
# P-valor do F-teste de médias iguais de peso para ambos os sexos: 0.00
# P-valor do F-teste de médias iguais de QI para ambos os sexos: 0.66

# %%
# Note que
